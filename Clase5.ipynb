# %% [markdown]
# <a href="https://colab.research.google.com/github/Noemigb2001-09/ai2023-2NoemiG/blob/main/Clase5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pandas has two data structer
# Series
import pandas as pd
tmp=pd.Series(data=[100,200,300,400], index=['Carlos', 'Juan', 'Mario', 'Rosita'])

# %%
print (tmp)
# Out:
# Carlos    100
# Juan      200
# Mario     300
# Rosita    400
# dtype: int64

# %%
tmp.shape
# Out:
# (4,)

# %%
print(tmp[-2])
# Out:
# 300

# %%
tmp*2
# Out:
# Carlos    200
# Juan      400
# Mario     600
# Rosita    800
# dtype: int64

# %%
tmp[[1,2,3]]
print('___________________')
print(tmp[[1,2,3]])
# Out:
# ___________________
# Juan      200
# Mario     300
# Rosita    400
# dtype: int64

# %%
tmp.index
# Out:
# Index(['Carlos', 'Juan', 'Mario', 'Rosita'], dtype='object')

# %%
#creating a dictionary
my_dict = {'name': 'Jhon', 'age': 25, 'city': 'New York'}

# %%
aux={'one':pd.Series([1,2,3],index=['apple', 'boll', 'clock']),
     'two':pd.Series([10,20,30],index=['pineapple', 'watermelon', 'banana'])}

# %%
aux
# Out:
# {'one': apple    1
#  boll     2
#  clock    3
#  dtype: int64,
#  'two': pineapple     10
#  watermelon    20
#  banana        30
#  dtype: int64}

# %%
df=pd.DataFrame(aux)

# %%
df.shape
# Out:
# (6, 2)

# %%
df
# Out:
#             one   two
# apple       1.0   NaN
# banana      NaN  30.0
# boll        2.0   NaN
# clock       3.0   NaN
# pineapple   NaN  10.0
# watermelon  NaN  20.0

# %%
df.index
# Out:
# Index(['apple', 'banana', 'boll', 'clock', 'pineapple', 'watermelon'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
df['three']=df['one']*df['two']

# %%
df
# Out:
#             one   two  four  filtro  three
# apple       1.0   NaN   NaN   False    NaN
# banana      NaN  30.0   NaN   False    NaN
# boll        2.0   NaN   NaN   False    NaN
# clock       3.0   NaN   NaN    True    NaN
# pineapple   NaN  10.0   NaN   False    NaN
# watermelon  NaN  20.0   NaN   False    NaN

# %%
df['four']=df['one']*df['two']
df
# Out:
#             one   two  four  filtro  three
# apple       1.0   NaN   NaN   False    NaN
# banana      NaN  30.0   NaN   False    NaN
# boll        2.0   NaN   NaN   False    NaN
# clock       3.0   NaN   NaN    True    NaN
# pineapple   NaN  10.0   NaN   False    NaN
# watermelon  NaN  20.0   NaN   False    NaN

# %%
df['filtro']=df['one']>2
df
# Out:
#             one   two  four  filtro  three
# apple       1.0   NaN   NaN   False    NaN
# banana      NaN  30.0   NaN   False    NaN
# boll        2.0   NaN   NaN   False    NaN
# clock       3.0   NaN   NaN    True    NaN
# pineapple   NaN  10.0   NaN   False    NaN
# watermelon  NaN  20.0   NaN   False    NaN

# %%
# primera manera de borrar
del df['three']
df
# Out:
#             one   two  four  filtro
# apple       1.0   NaN   NaN   False
# banana      NaN  30.0   NaN   False
# boll        2.0   NaN   NaN   False
# clock       3.0   NaN   NaN    True
# pineapple   NaN  10.0   NaN   False
# watermelon  NaN  20.0   NaN   False

# %%
#segunda manera de eliminar
df2=df.pop('four')

# %%
df
# Out:
#             one   two  filtro
# apple       1.0   NaN   False
# banana      NaN  30.0   False
# boll        2.0   NaN   False
# clock       3.0   NaN    True
# pineapple   NaN  10.0   False
# watermelon  NaN  20.0   False

# %%
#CLASS STUDY
