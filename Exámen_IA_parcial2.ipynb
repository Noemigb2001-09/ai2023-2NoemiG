# %% [markdown]
# <a href="https://colab.research.google.com/github/Noemigb2001-09/ai2023-2NoemiG/blob/main/Ex%C3%A1men_IA_parcial2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#importar la BD
url = 'https://raw.githubusercontent.com/Sinchiguano/ai_googleColab/main/datasetUleamMl/IRIS.csv'
df = pd.read_csv(url)
print(df.head(10))
#Mostrar los 10 primeros registros
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# ...

# %%
df.shape
# Out:
# (150, 5)

# %%
#import pandas as pd

# Supongamos que ya has cargado el conjunto de datos en un DataFrame llamado iris_df
url = 'https://raw.githubusercontent.com/Sinchiguano/ai_googleColab/main/datasetUleamMl/IRIS.csv'
iris_df = pd.read_csv(url)

# Mostrar valores nulos por columna
valores_nulos = iris_df.isnull().sum()

# Filtrar solo las columnas con valores nulos
columnas_con_nulos = valores_nulos[valores_nulos > 0]

# Mostrar los resultados
if columnas_con_nulos.empty:
    print("No hay valores nulos en el DataFrame.")
else:
    print("Columnas con valores nulos:")
    print(columnas_con_nulos)
# Out:
# No hay valores nulos en el DataFrame.

# %%
df.columns
df.shape
# Out:
# (150, 5)

# %%
#import pandas as pd

# Supongamos que ya has cargado el conjunto de datos en un DataFrame llamado iris_df
url = 'https://raw.githubusercontent.com/Sinchiguano/ai_googleColab/main/datasetUleamMl/IRIS.csv'
iris_df = pd.read_csv(url)

# Conteo rápido de las especies
conteo_especies = iris_df['species'].value_counts()

# Mostrar el conteo de especies
print("Conteo rápido de especies:")
print(conteo_especies)

# Obtener las muestras de cada especie
for especie in conteo_especies.index:
    muestras_especie = iris_df[iris_df['species'] == especie]
    print(f"\nMuestras de la especie {especie}:")
    print(muestras_especie)
# Out:
# Conteo rápido de especies:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64
#
# Muestras de la especie Iris-setosa:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# ...

# %%
#conteo de datos
df['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Cargar el conjunto de datos Iris de sklearn
iris = load_iris()
data = pd.DataFrame(data=iris.data, columns=iris.feature_names)
data['target'] = iris.target
data['species'] = iris.target_names[data['target']]

# Trama de pares usando Seaborn
sns.set(style="ticks")
sns.pairplot(data, hue="species")
plt.show()

# %%
#visualizar gráfico de las especies Iris
sb.pairplot(df, hue='species', markers='+')

# %%
filtro_setosa = df['species'] == 'Iris-setosa'
filtro_versicolor = df['species'] == 'Iris-versicolor'
filtro_virginica = df['species'] == 'Iris-virginica'

# Aplicar los filtros y contar las muestras para cada especie
muestras_setosa = df[filtro_setosa].shape[0]
muestras_versicolor = df[filtro_versicolor].shape[0]
muestras_virginica = df[filtro_virginica].shape[0]

# Mostrar el número de muestras por especie
print("Número de muestras para setosa:", muestras_setosa)
print("Número de muestras para versicolor:", muestras_versicolor)
print("Número de muestras para virginica:", muestras_virginica)
# Out:
# Número de muestras para setosa: 50
# Número de muestras para versicolor: 50
# Número de muestras para virginica: 50

# %%
df['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
especies_unicas = df['species'].unique()

# Mostrar las especies únicas
print("Tipos únicos de especies:")
print(especies_unicas)
# Out:
# Tipos únicos de especies:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
import matplotlib.pyplot as plt

# %%
virginica = df[df['species'] == 'virginica']

# %%
# # Filtrar el DataFrame para las especies 'virginica', 'setosa' y 'versicolor'
# virginica = df[df['species'] == 'virginica']
# setosa = df[df['species'] == 'setosa']
# versicolor = df[df['species'] == 'versicolor']

# # Crear un gráfico de dispersión para 'sepal_length' vs 'sepal_width'
# fig, axis = plt.subplots()
# fig.set_size_inches(10, 5)

# # Scatter plot para Virginica
# axis.scatter(virginica['petal_length'], virginica['sepal_width'], facecolor='green', label='virginica')

# # Scatter plot para Setosa
# axis.scatter(setosa['petal_length'], setosa['sepal_width'], facecolor='blue', label='setosa')

# # Scatter plot para Versicolor
# axis.scatter(versicolor['petal_length'], versicolor['sepal_width'], facecolor='red', label='versicolor')

# axis.set_xlabel('sepal_length')
# axis.set_ylabel('sepal_width')
# axis.set_title('sepal_length vs sepal_width')
# axis.grid()
# axis.legend()
# plt.show()

# %%
df.head()
del df['petal_length']
del df['sepal_width']

# %%
df.head()
# Out:
#    sepal_length  petal_width      species
# 0           5.1          0.2  Iris-setosa
# 1           4.9          0.2  Iris-setosa
# 2           4.7          0.2  Iris-setosa
# 3           4.6          0.2  Iris-setosa
# 4           5.0          0.2  Iris-setosa

# %%
df['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# Método 1: Usando iterrows y declaraciones if/else
#df['target'] =df['species'].map[{'Iris-setosa':1, 'Iris-versicolor':2,'Iris-virginica':3}]
df['target'] = df['species'].map({'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2})
df.head(120)
# Out:
#      sepal_length  petal_width         species  target
# 0             5.1          0.2     Iris-setosa       0
# 1             4.9          0.2     Iris-setosa       0
# 2             4.7          0.2     Iris-setosa       0
# 3             4.6          0.2     Iris-setosa       0
# 4             5.0          0.2     Iris-setosa       0
# ..            ...          ...             ...     ...
# 115           6.4          2.3  Iris-virginica       2
# 116           6.5          1.8  Iris-virginica       2
# 117           7.7          2.2  Iris-virginica       2
# 118           7.7          2.3  Iris-virginica       2
# 119           6.0          1.5  Iris-virginica       2
#
# [120 rows x 4 columns]

# %%
y=df['target']

# %%
x=df.drop(['target','species'], axis=1)

# %%
x.head(5)
# Out:
#    sepal_length  petal_width
# 0           5.1          0.2
# 1           4.9          0.2
# 2           4.7          0.2
# 3           4.6          0.2
# 4           5.0          0.2

# %%
type(x)
x.shape
import numpy as np
x=x.to_numpy()
print(type(x))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# dividir el set de datos

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3, random_state=240)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(xtrain, ytrain)
# Out:
# LogisticRegression()

# %%
predictions=model.predict(xtest)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_true=ytest,y_pred=predictions)
# Out:
# 1.0
